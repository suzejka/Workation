# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import streamlit as st
from pycaret.regression import *

# %%
LABEL_ENCODER = None

def remove_null(data):
    data.dropna(inplace=True)
    return data

def convert_dates_to_one_format(data):
    data['Travel Date'] = pd.to_datetime(data['Travel Date'], errors='coerce')
    data['Travel Date'] = data['Travel Date'].dt.strftime('%Y-%m-%d')
    return data

def replace_space_with_underscore(name):
    return name.replace(' ', '_')

def create_label_encoding(data):
    global LABEL_ENCODER
    cat_cols = data.select_dtypes(include=['object']).columns
    LABEL_ENCODER = LabelEncoder()
    for col in cat_cols:
        data[col] = LABEL_ENCODER.fit_transform(data[col])
        np.save('classes_{0}.npy'.format(replace_space_with_underscore(col)), LABEL_ENCODER.classes_, allow_pickle=True)

def change_int32_to_int64(data):
    for col in data.columns:
        if data[col].dtype == 'int64':
            data[col] = data[col].astype('int32')

def data_preprocessing(data):
    data.drop(['Uniq Id'], axis=1, inplace=True)
    remove_null(data)
    change_int32_to_int64(data)
    convert_dates_to_one_format(data)
    create_label_encoding(data)

def find_best_models(train):
    rgs1 = setup(data = train, target = "Per Person Price", silent=True)
    best_regression_models = compare_models()
    return best_regression_models

def create_best_model():
    best_model = create_model('rf') #random forest chosen from find_best_model()
    return best_model

# %%
train = pd.read_csv('dataset\Train.csv')
display(train)
# Out:
#                                 Uniq Id  \
# 0      e788ab76d9d8cf1e6ed2f139645ca5d1
# 1      178f892630ce3e335a5a41d5d83937fd
# 2      f060f2954840503cc2fdaf495357b7df
# 3      32a19a6c171e67448f2346da46c619dc
# 4      107b068aa0ca03bc6248966f594d105f
# ...                                 ...
# 20995  ae3ae6ca299180d470145a0e154cbf2b
# 20996  6ccc538e3597a909f609fcb2eba9be5e
# 20997  d3b412fa94ce5503204024c6db2f60b7
# 20998  51d843fb852ec7abde8299fe31111bd5
# 20999  5ed596587aba74b3f52a59384c04b5a4
#
#                                             Package Name Package Type  \
# 0           Best of Shimla and Manali Holiday from Delhi     Standard
# 1                                Kashmir Valley vacation      Premium
# 2                Might of Mewar- Udaipur and Chittorgarh       Luxury
# 3                   Colorful Kerala ( Romantic Getaway )      Premium
# 4                            A Week In Bangkok & Pattaya      Premium
# ...                                                  ...          ...
# 20995                 Shimla & Manali Retreat from Delhi       Deluxe
# 20996                         Bedazzling Kashmir Holiday       Luxury
# 20997  A relaxing week in Colombo (Bentota and Galle ...       Deluxe
# 20998                    Awesome North East with Pelling       Deluxe
# 20999                   Munnar, Kovalam, Allepey Holiday     Standard
#
#                                        Destination  \
# 0               New Delhi|Shimla|Manali|Chandigarh
# 1                       Srinagar|Pahalgam|Srinagar
# 2                              Udaipur|Chittorgarh
# 3      Munnar|Kumarakom|Allepey|Kovalam and Poovar
# 4                                  Pattaya|Bangkok
# ...                                            ...
# 20995                      Shimla|Manali|New Delhi
# 20996           Srinagar|Gulmarg|Pahalgam|Srinagar
# 20997                                      Colombo
# 20998                   Darjeeling|Pelling|Gangtok
# 20999                       Munnar|Kovalam|Allepey
#
#                                                Itinerary  \
# 0      1N New Delhi . 2N Shimla . 2N Manali . 1N Chan...
# 1                1N Srinagar . 2N Pahalgam . 1N Srinagar
# 2                            2N Udaipur . 1N Chittorgarh
# 3      2N Munnar . 1N Kumarakom . 1N Allepey . 2N Kov...
# 4                                4N Pattaya . 3N Bangkok
# ...                                                  ...
# 20995               2N Shimla . 3N Manali . 1N New Delhi
# 20996  1N Srinagar . 1N Gulmarg . 2N Pahalgam . 3N Sr...
# 20997                                         5N Colombo
# 20998            2N Darjeeling . 2N Pelling . 2N Gangtok
# 20999                3N Munnar . 2N Kovalam . 1N Allepey
#
#                                     Places Covered Travel Date  \
# 0               New Delhi|Shimla|Manali|Chandigarh  30-07-2021
# 1                       Srinagar|Pahalgam|Srinagar  08-12-2021
# 2                              Udaipur|Chittorgarh  26-04-2021
# 3      Munnar|Kumarakom|Allepey|Kovalam and Poovar  27-08-2021
# 4                                  Pattaya|Bangkok  12-12-2021
# ...                                            ...         ...
# 20995                      Shimla|Manali|New Delhi  15-04-2021
# 20996           Srinagar|Gulmarg|Pahalgam|Srinagar  30-08-2021
# 20997                                      Colombo  27-02-2021
# 20998                   Darjeeling|Pelling|Gangtok  13-01-2022
# 20999                       Munnar|Kovalam|Allepey  30-05-2021
#
#                                            Hotel Details Start City  \
# 0                                          Not Available     Mumbai
# 1      The Orchard Retreat & Spa:4.6|WelcomHotel Pine...  New Delhi
# 2           The Ananta:4.4|juSTa Lake Nahargarh Palace:4  New Delhi
# 3      Elixir Hills Suites Resort & Spa-MMT Holidays ...  New Delhi
# 4      Dusit Thani Pattaya - MMT Special:4.5|Amari Wa...  New Delhi
# ...                                                  ...        ...
# 20995  Summit Thistle Villa Resort & Spa:Four|Snow Va...     Mumbai
# 20996  The Orchard Retreat & Spa:4.6|The Khyber Himal...  New Delhi
# 20997       Mount Lavinia Hotel-MMT HOLIDAYS SPECIAL:4.0  New Delhi
# 20998  Ramada by Wyndham Darjeeling Gandhi Road:4.4|T...  New Delhi
# 20999  Iceberg Hill Hotel-MMT Holidays Special:3.8|Sa...  New Delhi
#
#                            Airline  Flight Stops  Meals  \
# 0                    Not Available             2      3
# 1                    IndiGo|IndiGo             0      5
# 2                           IndiGo             0      4
# 3                           IndiGo             0      5
# 4                  Spicejet|Go Air             0      5
# ...                            ...           ...    ...
# 20995                Not Available             1      3
# 20996              Vistara|Vistara             0      4
# 20997  IndiGo|IndiGo|IndiGo|IndiGo             1      3
# 20998                       IndiGo             1      3
# 20999                       IndiGo             2      3
#
#                               Sightseeing Places Covered  \
# 0                                          Not Available
# 1       Dal Lake | Avantipura Ruins | Mughal Gardens ...
# 2       Lake Pichola | Jag Mandir Palace | Saheliyon ...
# 3       Mattupetty Dam | Echo Point | Tata Tea Museum...
# 4       Coral Island Tour with Indian Lunch, Join Spe...
# ...                                                  ...
# 20995   Mall road | Indira Bunglow | Himalayan Zoo | ...
# 20996   Dal Lake | Gondola Point | Avantipura Ruins |...
# 20997       Sigiriya Excursion | Nuwara Eliya Excursion
# 20998   Tiger Hill | Himalayan Mountaineering Institu...
# 20999   Tata Tea Museum | Eravikulam national park | ...
#
#                                       Cancellation Rules  Per Person Price
# 0                                          Not Available           11509.0
# 1      Cancellation any time after making the 1st pay...           22485.5
# 2      Cancellation any time after making the 1st pay...           12421.5
# 3      Cancellation any time after making the 1st pay...           35967.0
# 4      Cancellation any time after making the 1st pay...           25584.0
# ...                                                  ...               ...
# 20995  Cancellation any time after making the 1st pay...           16168.5
# 20996  Cancellation any time after making the 1st pay...           33770.5
# 20997  Cancellation any time after making the 1st pay...           29964.0
# 20998  Cancellation any time after making the 1st pay...           28145.5
# 20999  Cancellation any time after making the 1st pay...           15736.0
#
# [21000 rows x 15 columns]

# %%
types = train.dtypes
print(types)
# Out:
# Uniq Id                        object
# Package Name                   object
# Package Type                   object
# Destination                    object
# Itinerary                      object
# Places Covered                 object
# Travel Date                    object
# Hotel Details                  object
# Start City                     object
# Airline                        object
# Flight Stops                    int64
# Meals                           int64
# Sightseeing Places Covered     object
# Cancellation Rules             object
# Per Person Price              float64
# dtype: object

# %%
validation = pd.read_csv('dataset\Test.csv')

# %%
data_preprocessing(train)
data_preprocessing(validation)

# %%
best = find_best_models(train)
# Out:
# <style type="text/css">
# #T_7b957 th {
#   text-align: left;
# }
# #T_7b957_row0_col0, #T_7b957_row1_col0, #T_7b957_row1_col1, #T_7b957_row1_col2, #T_7b957_row1_col3, #T_7b957_row1_col4, #T_7b957_row1_col5, #T_7b957_row1_col6, #T_7b957_row2_col0, #T_7b957_row2_col1, #T_7b957_row2_col2, #T_7b957_row2_col3, #T_7b957_row2_col4, #T_7b957_row2_col5, #T_7b957_row2_col6, #T_7b957_row3_col0, #T_7b957_row3_col1, #T_7b957_row3_col2, #T_7b957_row3_col3, #T_7b957_row3_col4, #T_7b957_row3_col5, #T_7b957_row3_col6, #T_7b957_row4_col0, #T_7b957_row4_col1, #T_7b957_row4_col2, #T_7b957_row4_col3, #T_7b957_row4_col4, #T_7b957_row4_col5, #T_7b957_row4_col6, #T_7b957_row5_col0, #T_7b957_row5_col1, #T_7b957_row5_col2, #T_7b957_row5_col3, #T_7b957_row5_col4, #T_7b957_row5_col5, #T_7b957_row5_col6, #T_7b957_row6_col0, #T_7b957_row6_col1, #T_7b957_row6_col2, #T_7b957_row6_col3, #T_7b957_row6_col4, #T_7b957_row6_col5, #T_7b957_row6_col6, #T_7b957_row7_col0, #T_7b957_row7_col1, #T_7b957_row7_col2, #T_7b957_row7_col3, #T_7b957_row7_col4, #T_7b957_row7_col5, #T_7b957_row7_col6, #T_7b957_row8_col0, #T_7b957_row8_col1, #T_7b957_row8_col2, #T_7b957_row8_col3, #T_7b957_row8_col4, #T_7b957_row8_col5, #T_7b957_row8_col6, #T_7b957_row9_col0, #T_7b957_row9_col1, #T_7b957_row9_col2, #T_7b957_row9_col3, #T_7b957_row9_col4, #T_7b957_row9_col5, #T_7b957_row9_col6, #T_7b957_row10_col0, #T_7b957_row10_col1, #T_7b957_row10_col2, #T_7b957_row10_col3, #T_7b957_row10_col4, #T_7b957_row10_col5, #T_7b957_row10_col6, #T_7b957_row11_col0, #T_7b957_row11_col1, #T_7b957_row11_col2, #T_7b957_row11_col3, #T_7b957_row11_col4, #T_7b957_row11_col5, #T_7b957_row11_col6, #T_7b957_row12_col0, #T_7b957_row12_col1, #T_7b957_row12_col2, #T_7b957_row12_col3, #T_7b957_row12_col4, #T_7b957_row12_col5, #T_7b957_row12_col6, #T_7b957_row13_col0, #T_7b957_row13_col1, #T_7b957_row13_col2, #T_7b957_row13_col3, #T_7b957_row13_col4, #T_7b957_row13_col5, #T_7b957_row13_col6, #T_7b957_row14_col0, #T_7b957_row14_col1, #T_7b957_row14_col2, #T_7b957_row14_col3, #T_7b957_row14_col4, #T_7b957_row14_col5, #T_7b957_row14_col6, #T_7b957_row15_col0, #T_7b957_row15_col1, #T_7b957_row15_col2, #T_7b957_row15_col3, #T_7b957_row15_col4, #T_7b957_row15_col5, #T_7b957_row15_col6, #T_7b957_row16_col0, #T_7b957_row16_col1, #T_7b957_row16_col2, #T_7b957_row16_col3, #T_7b957_row16_col4, #T_7b957_row16_col5, #T_7b957_row16_col6, #T_7b957_row17_col0, #T_7b957_row17_col1, #T_7b957_row17_col2, #T_7b957_row17_col3, #T_7b957_row17_col4, #T_7b957_row17_col5, #T_7b957_row17_col6 {
#   text-align: left;
# }
# #T_7b957_row0_col1, #T_7b957_row0_col2, #T_7b957_row0_col3, #T_7b957_row0_col4, #T_7b957_row0_col5, #T_7b957_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7b957_row0_col7, #T_7b957_row1_col7, #T_7b957_row2_col7, #T_7b957_row3_col7, #T_7b957_row4_col7, #T_7b957_row5_col7, #T_7b957_row6_col7, #T_7b957_row7_col7, #T_7b957_row8_col7, #T_7b957_row9_col7, #T_7b957_row10_col7, #T_7b957_row11_col7, #T_7b957_row12_col7, #T_7b957_row13_col7, #T_7b957_row14_col7, #T_7b957_row16_col7, #T_7b957_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7b957_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7b957">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b957_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7b957_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7b957_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7b957_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7b957_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7b957_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7b957_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7b957_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b957_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_7b957_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_7b957_row0_col1" class="data row0 col1" >3580.1378</td>
#       <td id="T_7b957_row0_col2" class="data row0 col2" >40102586.8843</td>
#       <td id="T_7b957_row0_col3" class="data row0 col3" >6307.5632</td>
#       <td id="T_7b957_row0_col4" class="data row0 col4" >0.7081</td>
#       <td id="T_7b957_row0_col5" class="data row0 col5" >0.2550</td>
#       <td id="T_7b957_row0_col6" class="data row0 col6" >0.1948</td>
#       <td id="T_7b957_row0_col7" class="data row0 col7" >1.6030</td>
#     </tr>
#     <tr>
#       <th id="T_7b957_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_7b957_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7b957_row1_col1" class="data row1 col1" >4048.1617</td>
#       <td id="T_7b957_row1_col2" class="data row1 col2" >42818570.1881</td>
#       <td id="T_7b957_row1_col3" class="data row1 col3" >6520.4599</td>
#       <td id="T_7b957_row1_col4" class="data row1 col4" >0.6887</td>
#       <td id="T_7b957_row1_col5" class="data row1 col5" >0.2788</td>
#       <td id="T_7b957_row1_col6" class="data row1 col6" >0.2273</td>
#       <td id="T_7b957_row1_col7" class="data row1 col7" >0.0910</td>
#     </tr>
#     <tr>
#       <th id="T_7b957_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_7b957_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_7b957_row2_col1" class="data row2 col1" >3735.7401</td>
#       <td id="T_7b957_row2_col2" class="data row2 col2" >43120615.2324</td>
#       <td id="T_7b957_row2_col3" class="data row2 col3" >6540.8535</td>
#       <td id="T_7b957_row2_col4" class="data row2 col4" >0.6860</td>
#       <td id="T_7b957_row2_col5" class="data row2 col5" >0.2652</td>
#       <td id="T_7b957_row2_col6" class="data row2 col6" >0.2037</td>
#       <td id="T_7b957_row2_col7" class="data row2 col7" >1.2620</td>
#     </tr>
#     <tr>
#       <th id="T_7b957_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_7b957_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_7b957_row3_col1" class="data row3 col1" >5052.4910</td>
#       <td id="T_7b957_row3_col2" class="data row3 col2" >61336738.7032</td>
#       <td id="T_7b957_row3_col3" class="data row3 col3" >7818.7912</td>
#       <td id="T_7b957_row3_col4" class="data row3 col4" >0.5532</td>
#       <td id="T_7b957_row3_col5" class="data row3 col5" >0.3413</td>
#       <td id="T_7b957_row3_col6" class="data row3 col6" >0.2951</td>
#       <td id="T_7b957_row3_col7" class="data row3 col7" >0.8040</td>
#     </tr>
#     <tr>
#       <th id="T_7b957_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_7b957_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_7b957_row4_col1" class="data row4 col1" >4607.2288</td>
#       <td id="T_7b957_row4_col2" class="data row4 col2" >70763591.0109</td>
#       <td id="T_7b957_row4_col3" class="data row4 col3" >8396.4619</td>
#       <td id="T_7b957_row4_col4" class="data row4 col4" >0.4817</td>
#       <td id="T_7b957_row4_col5" class="data row4 col5" >0.3356</td>
#       <td id="T_7b957_row4_col6" class="data row4 col6" >0.2402</td>
#       <td id="T_7b957_row4_col7" class="data row4 col7" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_7b957_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_7b957_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_7b957_row5_col1" class="data row5 col1" >5745.1354</td>
#       <td id="T_7b957_row5_col2" class="data row5 col2" >81123768.0000</td>
#       <td id="T_7b957_row5_col3" class="data row5 col3" >8996.9377</td>
#       <td id="T_7b957_row5_col4" class="data row5 col4" >0.4071</td>
#       <td id="T_7b957_row5_col5" class="data row5 col5" >0.4108</td>
#       <td id="T_7b957_row5_col6" class="data row5 col6" >0.3506</td>
#       <td id="T_7b957_row5_col7" clas
# 2023-01-05 17:42:30.836 INFO    logs: create_model_container: 18
# 2023-01-05 17:42:30.838 INFO    logs: master_model_container: 18
# 2023-01-05 17:42:30.839 INFO    logs: display_container: 2
# 2023-01-05 17:42:30.841 INFO    logs: RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=5503, verbose=0, warm_start=False)
# 2023-01-05 17:42:30.842 INFO    logs: compare_models() succesfully completed......................................

# %%
results = pull()
print(best)
save_model(best, 'random_forest_model')
# Out:
# 2023-01-05 17:44:56.977 INFO    logs: Initializing save_model()
# 2023-01-05 17:44:56.985 INFO    logs: save_model(model=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=5503, verbose=0, warm_start=False), model_name=random_forest_model, prep_pipe_=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[],
#                                       target='Per Person Price',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_...
#                 ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                 ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                 ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='Per Person Price')),
#                 ('fix_perfect', Remove_100(target='Per Person Price')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False), verbose=True, kwargs={})
# 2023-01-05 17:44:56.989 INFO    logs: Adding model into prep_pipe
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=5503, verbose=0, warm_start=False)
# 2023-01-05 17:44:57.249 INFO    logs: random_forest_model.pkl saved in current working directory
# 2023-01-05 17:44:57.253 INFO    logs: Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[],
#                                       target='Per Person Price',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_...
#                  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                        criterion='mse', max_depth=None,
#                                        max_features='auto', max_leaf_nodes=None,
#                                        max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=100, n_jobs=-1,
#                                        oob_score=False, random_state=5503,
#                                        verbose=0, warm_start=False)]],
#          verbose=False)
# 2023-01-05 17:44:57.262 INFO    logs: save_model() successfully completed......................................
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[],
#                                        target='Per Person Price',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_...
#                   RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                         criterion='mse', max_depth=None,
#                                         max_features='auto', max_leaf_nodes=None,
#                                         max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=-1,
#                                         oob_score=False, random_state=5503,
#                                         verbose=0, warm_start=False)]],
#           verbose=False),
#  'random_forest_model.pkl')
